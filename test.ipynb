# %%
import torch

# %%
# setting device on GPU if available, else CPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
print()

#Additional Info when using cuda
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_reserved(0)/1024**3,1), 'GB')
# Out:
# Using device: cuda
#
# NVIDIA GeForce RTX 4090
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB

# %%
# load image
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('/home/bingwang/Documents/blender_assert/Cube_Monkey/test.png')

# %%
# for loop pixels in img
value_set = set()
for i in range(0, img.shape[0]):
    for j in range(0, img.shape[1]):
        pixel_val = img[i, j]
        value_set.add(tuple(pixel_val))

# %%
# show pixel value colors
plt.subplot(1, 2, 1)
plt.imshow(img)
plt.subplot(1, 2, 2)
plt.title('LEFT TOP 5x5 PIXELS')
plt.imshow(img[:5, :5])

# %%
print(img[:5, :5])
# Out:
# [[[ 29 255  53]
#   [ 29 255  53]
#   [ 29 255  53]
#   [ 29 255  53]
#   [ 29 255  53]]
#
#  [[ 29 255  53]
#   [ 29 255  53]
#   [ 29 255  53]
#   [ 29 255  53]
#   [ 29 255  53]]
#
#  [[ 29 255  53]
#   [ 29 255  53]
#   [ 29 255  53]
#   [ 29 255  53]
#   [ 29 255  53]]
#
#  [[ 29 255  53]
#   [ 29 255  53]
#   [ 29 255  53]
#   [ 29 255  53]
#   [ 29 255  53]]
#
#  [[ 29 255  53]
#   [ 29 255  53]
#   [ 29 255  53]
#   [ 29 255  53]
#   [ 29 255  53]]]

# %%
# show pixel value colors of set value_set as bar
plt.figure()
plt.imshow([list(value_set)], aspect='auto')
